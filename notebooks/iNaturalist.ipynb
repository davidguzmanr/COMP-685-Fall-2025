# %% [markdown]
# To get the data [iNaturalist Research-grade Observations](https://www.gbif.org/dataset/50c9509d-22c7-4a22-a47d-8c48425ef4a7) run this in the terminal
#
#
# ```bash
# mkdir data
# cd data
# wget https://api.gbif.org/v1/occurrence/download/request/0011012-251025141854904.zip
# unzip 0011012-251025141854904.zip
# ```

# %%
import duckdb
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
# Run this only once

# Create or connect to a persistent DB
con = duckdb.connect('data/iNaturalist.duckdb')
print("connected")

# Import TSV once
con.execute("""
    CREATE TABLE IF NOT EXISTS iNaturalist AS
        SELECT * 
        FROM read_csv_auto('../data/0011983-251025141854904.csv', sep='\t', header=True);
""")
print("created iNaturalist.duckdb")

# Optionally add indexes
con.execute("PRAGMA enable_object_cache;")
print("add indexes")


# Query repeatedly without rereading the TSV
result = con.execute("""
    SELECT COUNT(*)
    FROM iNaturalist

""").df()

result.head()
# Out:
# connected

# %%
con = duckdb.connect('data/iNaturalist.duckdb')
print("connected!")
# Out:
# connected!

# %%
query = """
SELECT COUNT(*) AS observation_count
FROM iNaturalist
"""
df = con.execute(query).df()
df
# Out:
#    observation_count
# 0          131470382

# %%
query = """
SELECT *
FROM iNaturalist
LIMIT 5
"""
df = con.execute(query).df()
df
# Out:
#        gbifID                            datasetKey  \
# 0  4868040692  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  4416978367  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID  kingdom        phylum  \
# 0  https://www.inaturalist.org/observations/18469...  Plantae  Tracheophyta
# 1  https://www.inaturalist.org/observations/18476...  Plantae  Tracheophyta
#
#            class     order         family    genus              species  \
# 0  Magnoliopsida  Lamiales  Linderniaceae  Torenia     Torenia concolor
# 1  Magnoliopsida  Ericales    Primulaceae  Samolus  Samolus parviflorus
#
#   infraspecificEpithet taxonRank            scientificName  \
# 0                 None   SPECIES   Torenia concolor Lindl.
# 1                 None   SPECIES  Samolus parviflorus Raf.
#
#   verbatimScientificName verbatimScientificNameAuthorship countryCode  \
# 0       Torenia concolor                             None          TW
# 1    Samolus parviflorus                             None          US
#
#   locality stateProvince occurrenceStatus individualCount  \
# 0     None        Taiwan          PRESENT            None
# 1     None       Indiana          PRESENT            None
#
#                        publishingOrgKey  decimalLatitude  decimalLongitude  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d        23.912801        120.887476
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d        40.192580        -85.400362
#
#    coordinateUncertaintyInMeters coordinatePrecision elevation  \
# 0                            NaN                None      None
# 1                           34.0                None      None
#
#   elevationAccuracy depth depthAccuracy            eventDate  day  month  \
# 0              None  None          None     2023-09-24T10:00   24      9
# 1              None  None          None  2023-09-24T15:57:17   24      9
#
#    year  taxonKey  speciesKey      basisOfRecord institutionCode  \
# 0  2023   7331731     7331731  HUMAN_OBSERVATION     iNaturalist
# 1  2023   4005796     4005796  HUMAN_OBSERVATION     iNaturalist
#
#   collectionCode  catalogNumber recordNumber identifiedBy      dateIdentified  \
# 0   Observations      184692892         None            祐 2023-09-24 14:10:04
# 1   Observations      184760814         None        lsodo 2023-09-24 20:48:04
#
#         license rightsHolder recordedBy typeStatus establishmentMeans  \
# 0     CC_BY_4_0            祐          祐       None               None
# 1  CC_BY_NC_4_0        lsodo      lsodo       None               None
#
#                    lastInterpreted  \
# 0 2025-10-27 18:16:30.103000-04:00
# 1 2025-10-27 18:16:31.279000-04:00
#
#                                      mediaType  \
# 0                                   StillImage
# 1  StillImage;StillImage;StillImage;StillImage
#
#                                                issue
# 0  COORDINATE_ROUNDED;CONTINENT_DERIVED_FROM_COOR...
# 1  COORDINATE_ROUNDED;CONTINENT_DERIVED_FROM_COOR...

# %%
query = """
SELECT verbatimScientificName, COUNT(*) AS observation_count
FROM iNaturalist
GROUP BY verbatimScientificName
ORDER BY observation_count DESC
"""

df = con.execute(query).df()
df
# Out:
#            verbatimScientificName  observation_count
# 0              Anas platyrhynchos             491873
# 1                  Apis mellifera             422116
# 2               Harmonia axyridis             317456
# 3               Passer domesticus             306767
# 4                Danaus plexippus             295071
# ...                           ...                ...
# 483352  Neolepolepis occidentalis                  1
# 483353        Copestylum willinki                  1
# 483354  Acanthonotozoma cristatum                  1
# 483355      Triodia danthonioides                  1
# 483356     Hamamelis × intermedia                  1
#
# [483357 rows x 2 columns]

# %%
# query = """
# SELECT 
#     verbatimScientificName,
#     STRFTIME(
#         TRY_STRPTIME(eventDate, ['%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H:%M', '%Y-%m-%d']),
#         '%Y-%m-%d %H:%M:%S'
#     ) AS eventDate,
#     decimalLatitude,
#     decimalLongitude,
#     countryCode
# FROM iNaturalist
# WHERE 
#     decimalLatitude IS NOT NULL
#     AND decimalLongitude IS NOT NULL
#     AND eventDate IS NOT NULL
# LIMIT 10
# """

# df = con.execute(query).df()
# df
# Out:
#   verbatimScientificName            eventDate  decimalLatitude  \
# 0       Torenia concolor  2023-09-24 10:00:00        23.912801
# 1    Samolus parviflorus  2023-09-24 15:57:17        40.192580
# 2    Harpaphe haydeniana  2020-05-24 16:33:17        37.262108
# 3      Polistes dominula  2020-05-26 11:07:43        40.701724
# 4       Mergus merganser  2020-05-08 00:00:00        45.501143
# 5        Bombus pratorum  2020-05-26 12:59:00        52.490877
# 6     Lotus corniculatus  2020-05-28 17:41:36        38.968353
# 7  Anthriscus sylvestris  2020-05-29 16:35:00        55.824916
# 8     Lamium galeobdolon  2020-05-30 13:08:05        50.975306
# 9     Setophaga magnolia  2020-05-30 09:20:00        43.945995
#
#    decimalLongitude countryCode
# 0        120.887476          TW
# 1        -85.400362          US
# 2       -122.241436          US
# 3        -73.996270          US
# 4       -122.306145          US
# 5         13.321534          DE
# 6        -84.430620          US
# 7         37.573990          RU
# 8         14.037483          DE
# 9        -76.879598          CA

# %%
query = """
WITH clean_iNaturalist AS (
    SELECT
        verbatimScientificName,
        STRFTIME(
            TRY_STRPTIME(eventDate, ['%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H:%M', '%Y-%m-%d']),
            '%Y-%m-%d'
        ) AS dateOcurrence,  -- keep only the date part
        decimalLatitude,
        decimalLongitude,
        countryCode
    FROM iNaturalist
    WHERE
        decimalLatitude IS NOT NULL
        AND decimalLongitude IS NOT NULL
        AND eventDate IS NOT NULL AND TRIM(eventDate) <> '' 
        AND dateOcurrence IS NOT NULL AND TRIM(dateOcurrence) <> ''
        AND TRY_STRPTIME(eventDate, ['%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H:%M', '%Y-%m-%d']) > TIMESTAMP '2025-01-01'
        AND verbatimScientificName = 'Danaus plexippus'
)

SELECT
    verbatimScientificName,
    dateOcurrence,
    decimalLatitude,
    decimalLongitude,
    countryCode,
    COUNT(*) AS countOccurrences
FROM clean_iNaturalist
GROUP BY
    verbatimScientificName,
    dateOcurrence,
    decimalLatitude,
    decimalLongitude,
    countryCode
ORDER BY
    dateOcurrence;
"""
df = con.execute(query).df()
df
# Out:
#       verbatimScientificName dateOcurrence  decimalLatitude  decimalLongitude  \
# 0           Danaus plexippus    2025-01-01       -34.806677        138.663421
# 1           Danaus plexippus    2025-01-01        35.129267       -120.632411
# 2           Danaus plexippus    2025-01-01        18.369262        -65.634262
# 3           Danaus plexippus    2025-01-01        33.718342       -118.289008
# 4           Danaus plexippus    2025-01-01        28.032774        -82.781269
# ...                      ...           ...              ...               ...
# 54023       Danaus plexippus    2025-10-21        30.070267        -95.739158
# 54024       Danaus plexippus    2025-10-21        37.885839       -122.298224
# 54025       Danaus plexippus    2025-10-21        37.885922       -122.298266
# 54026       Danaus plexippus    2025-10-21        37.885900       -122.298221
# 54027       Danaus plexippus    2025-10-21        36.063756        -94.177995
#
#       countryCode  countOccurrences
# 0              AU                 1
# 1              US                 1
# 2              PR                 1
# 3              US                 1
# 4              US                 1
# ...           ...               ...
# 54023          US                 1
# 54024          US                 1
# 54025          US                 1
# 54026          US                 1
# 54027          US                 1
#
# [54028 rows x 6 columns]

# %%
# Aggregate by date and time
query = """
WITH clean_iNaturalist AS (
    SELECT
        verbatimScientificName,
        STRFTIME(
            TRY_STRPTIME(eventDate, ['%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H:%M', '%Y-%m-%d']),
            '%Y-%m-%d %H:%M:%S'
        ) AS dateOcurrence,  -- keep full datetime
        decimalLatitude,
        decimalLongitude,
        countryCode
    FROM iNaturalist
    WHERE
        decimalLatitude IS NOT NULL
        AND decimalLongitude IS NOT NULL
        AND eventDate IS NOT NULL AND TRIM(eventDate) <> ''
        AND TRY_STRPTIME(eventDate, ['%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H:%M', '%Y-%m-%d']) > TIMESTAMP '2000-01-01'
        AND verbatimScientificName = 'Danaus plexippus'
)

SELECT
    verbatimScientificName,
    dateOcurrence,
    decimalLatitude,
    decimalLongitude,
    countryCode,
    COUNT(*) AS countOccurrences
FROM clean_iNaturalist
GROUP BY
    verbatimScientificName,
    dateOcurrence,
    decimalLatitude,
    decimalLongitude,
    countryCode
ORDER BY
    dateOcurrence;
"""

df = con.execute(query).df()
df
# Out:
#        verbatimScientificName        dateOcurrence  decimalLatitude  \
# 0            Danaus plexippus  2000-01-29 19:46:00        35.263600
# 1            Danaus plexippus  2000-01-29 20:14:00        35.263712
# 2            Danaus plexippus  2000-01-29 20:15:00        35.263638
# 3            Danaus plexippus  2000-02-28 21:44:00        20.607068
# 4            Danaus plexippus  2000-04-27 16:20:00        36.099136
# ...                       ...                  ...              ...
# 280161       Danaus plexippus  2025-10-21 17:05:35        33.012233
# 280162       Danaus plexippus  2025-10-21 17:19:44        33.465848
# 280163       Danaus plexippus  2025-10-21 17:30:21        36.704885
# 280164       Danaus plexippus  2025-10-21 18:22:53       -32.340301
# 280165       Danaus plexippus  2025-10-21 20:05:27        33.012264
#
#         decimalLongitude countryCode  countOccurrences
# 0            -120.638700          US                 1
# 1            -120.638812          US                 1
# 2            -120.638652          US                 1
# 3            -103.341398          MX                 1
# 4            -112.089027          US                 1
# ...                  ...         ...               ...
# 280161        -83.734720          US                 1
# 280162        -82.230231          US                 1
# 280163        -76.236060          US                 1
# 280164        116.013917          AU                 1
# 280165        -83.734620          US                 1
#
# [280166 rows x 6 columns]
